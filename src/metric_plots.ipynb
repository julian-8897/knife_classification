# %%
import matplotlib.pyplot as plt

# Initialize lists to hold the data
# epochs = []
# train_loss = []
# val_mAP = []

# # Parse the log file
# with open('logs\effnetb0_2linear_adamw_log.txt', 'r') as f:
#     for line in f:
#         if line.startswith('train'):
#             parts = line.split()
#             epochs.append(float(parts[2]))
#             train_loss.append(float(parts[4]))
        
#         if line.startswith('val'):
#             val_mAP.append(float(parts[6]))

# # Create the plot
# plt.figure(figsize=(10, 5))

# plt.subplot(1, 2, 1)
# plt.plot(epochs, train_loss, label='Train Loss')
# plt.yscale('log')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('Train Loss per Epoch')
# plt.grid(True)

# plt.subplot(1, 2, 2)
# plt.plot(epochs, val_mAP, label='Validation mAP', color='orange')
# plt.yscale
# plt.xlabel('Epoch')
# plt.ylabel('mAP')
# plt.title('Validation mAP per Epoch')
# plt.grid(True)

# plt.tight_layout()
# plt.show()
# List of log files
log_files = ['logs/effnetv2S-1linear_batchnorm_dropout.txt']

# Parse the log files
for log_file in log_files:
    epochs = []
    train_loss = []
    val_mAP = []
    with open(log_file, 'r') as f:
        for line in f:
            if line.startswith('train'):
                parts = line.split()
                epochs.append(float(parts[2]))
                train_loss.append(float(parts[4]))

            if line.startswith('val'):
                val_mAP.append(float(parts[6]))

# Create the plot
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
for log_file in log_files:
    plt.plot(epochs, train_loss, label='Train Loss - ' + log_file)
# plt.yscale('log')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train Loss per Epoch')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
for log_file in log_files:
    plt.plot(epochs, val_mAP, label='Validation mAP - ' + log_file, color='orange')
plt.xlabel('Epoch')
plt.ylabel('mAP')
plt.title('Validation mAP per Epoch')
plt.grid(True)
plt.legend()

# %%
# # List of log files
# log_files = ['logs/effnetv2S-1linear_batchnorm_dropout.txt']

# # Parse the log files
# for log_file in log_files:
#     with open(log_file, 'r') as f:
#         for line in f:
#             if line.startswith('train'):
#                 parts = line.split()
#                 epochs.append(float(parts[2]))
#                 train_loss.append(float(parts[4]))

#             if line.startswith('val'):
#                 val_mAP.append(float(parts[6]))

# # Create the plot
# plt.figure(figsize=(10, 5))

# plt.subplot(1, 2, 1)
# for log_file in log_files:
#     plt.plot(epochs, train_loss, label='Train Loss - ' + log_file)
# # plt.yscale('log')
# plt.xlabel('Epoch')
# plt.ylabel('Loss')
# plt.title('Train Loss per Epoch')
# plt.grid(True)
# plt.legend()

# plt.subplot(1, 2, 2)
# for log_file in log_files:
#     plt.plot(epochs, val_mAP, label='Validation mAP - ' + log_file, color='orange')
# plt.xlabel('Epoch')
# plt.ylabel('mAP')
# plt.title('Validation mAP per Epoch')
# plt.grid(True)
# plt.legend()
